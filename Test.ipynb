# %%
# !pip install spotipy
client_id = '6684ff8b358d404e882409860c714959'
client_secret = '963f64275d5c49949eff69f1784c1fa0'
# Out:
# ...
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\tanne\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\tanne\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\tanne\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\tanne\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\tanne\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\tanne\appdata\local\programs\python\python39\lib\site-packages)
#
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
features = sp.audio_features(tracks=["3NRDLYyqIXja0UElvdzjkB"])
print(features)
 
danceability = features[0]["danceability"]
energy = features[0]["energy"]
key = features[0]["key"]
mode = features[0]["mode"]
tempo = features[0]["tempo"]
valence = features[0]["valence"]
# Out:
# [{'danceability': 0.738, 'energy': 0.613, 'key': 6, 'loudness': -6.001, 'mode': 0, 'speechiness': 0.403, 'acousticness': 0.0169, 'instrumentalness': 0.0493, 'liveness': 0.0684, 'valence': 0.407, 'tempo': 127.988, 'type': 'audio_features', 'id': '3NRDLYyqIXja0UElvdzjkB', 'uri': 'spotify:track:3NRDLYyqIXja0UElvdzjkB', 'track_href': 'https://api.spotify.com/v1/tracks/3NRDLYyqIXja0UElvdzjkB', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3NRDLYyqIXja0UElvdzjkB', 'duration_ms': 368476, 'time_signature': 4}]

# %%
recommendation = sp.recommendations(seed_tracks=["3NRDLYyqIXja0UElvdzjkB"], target_danceability=danceability, target_energy=energy, target_key = key, target_mode = mode, target_tempo=tempo, target_valence = valence)
for i in range(0,19):
    name = recommendation["tracks"][i]["name"]
    artist = recommendation["tracks"][i]["artists"][0]["name"]
    print("Artist: ", artist)
    print("Track: ", name)
    print("")
    i += 1
# Out:
# Artist:  Porter Robinson
# Track:  Language - Instrumental
#
# Artist:  Mystery Skulls
# Track:  Ghost
#
# Artist:  Innerpartysystem
# Track:  Out of Touch
#
# Artist:  Singularity
# Track:  Vain (feat. Evan Duffy) - Original Mix
#
# Artist:  Tristam
# Track:  Devotion
#
# Artist:  Pogo
# Track:  No Worries
#
# Artist:  Porter Robinson
# Track:  Language - Extended Mix
#
# Artist:  Mystery Skulls
# Track:  Every Note
#
# Artist:  Aiobahn
# Track:  ここにいる - Stephen Walking Remix
#
# Artist:  Hollywood Principle
# Track:  Breathing Underwater - Ether Remix
#
# Artist:  Tristam
# Track:  I Remember
#
# Artist:  Sakuraburst
# Track:  Bespoken Islands
#
# Artist:  Porter Robinson
# Track:  Unison
#
# Artist:  GHOST DATA
# Track:  Lily Love
#
# Artist:  Martin Garrix
# Track:  There For You - Lione Remix
#
# Artist:  Anamanaguchi
# Track:  Prom Night - Lindsay Lowend Remix
#
# Artist:  Juventa
# Track:  Move Into Light - Koven Remix
#
# Artist:  Bossfight
# Track:  Elevatia
#
# ...

# %%
track = "Amish Paradise"
sp.search(limit=5,q=f"track:{track}", type="track" )
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3AAmish+Paradise&type=track&offset=0&limit=5',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1bDWGdIC2hardyt55nlQgG'},
#        'href': 'https://api.spotify.com/v1/artists/1bDWGdIC2hardyt55nlQgG',
#        'id': '1bDWGdIC2hardyt55nlQgG',
#        'name': '"Weird Al" Yankovic',
#        'type': 'artist',
#        'uri': 'spotify:artist:1bDWGdIC2hardyt55nlQgG'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
# ...
